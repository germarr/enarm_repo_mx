# %%
import pandas as pd
import duckdb
import os

# %%
files = os.listdir('data')
files = sorted([f for f in files if f.endswith('.csv')])[1:]
files = sorted(files, reverse=True)

# %%
def clean_string(s):
    # Convert to lowercase
    s = s.lower()
    # Replace spaces with underscores
    s = s.replace(" ", "_")
    # Remove special characters
    s = ''.join(e for e in s if e.isalnum() or e == '_')
    # Replace accented characters
    accents = {
        'á': 'a', 'é': 'e', 'í': 'i', 'ó': 'o', 'ú': 'u',
        'Á': 'a', 'É': 'e', 'Í': 'i', 'Ó': 'o', 'Ú': 'u',
        'ñ': 'n', 'Ñ': 'n'
    }
    for accent, replacement in accents.items():
        s = s.replace(accent, replacement)
    return s

listOfDates = [i.split(".")[0] for i in files]

procc_list = []

for index_file, read_file in enumerate(files):
    # print(listOfDates[index_file])
    # print(read_file)
    procc_file = duckdb.sql(f"""
            WITH base as (SELECT 
            CASE WHEN "Entidad Federativa" = 'DISTRITO FEDERAL' THEN 'CIUDAD DE MÉXICO' ELSE "Entidad Federativa" END as estado,
            "Facultad o Escuela de Medicina" as facultad,
            "Sustentante" as sustentante,
            "Seleccionado" as seleccionado,
            "Promedio General de Conocimientos Médicos" as promedio,
            ROUND(("Seleccionado"::INTEGER / "Sustentante"::INTEGER) * 100,2) as acceptance_rate,
            '{listOfDates[index_file]}' as date_id,
            '{listOfDates[index_file].split('_')[1]}' as year,
            FROM read_csv('data/{read_file}') WHERE "Sustentante" > 0 ),
            stats AS (
                SELECT 
                    AVG(acceptance_rate) AS mean_rate, 
                    STDDEV(acceptance_rate) AS stddev_rate 
                FROM base
            ),
            enhanced AS (
                SELECT *,
                    mean_rate,
                    stddev_rate,
                    ROUND(acceptance_rate + stddev_rate,2) AS acceptance_rate_plus_1_std,
                    ROUND(acceptance_rate - stddev_rate,2) AS acceptance_rate_minus_1_std,
                    ROUND((acceptance_rate - mean_rate) / stddev_rate,2) AS z_index
                FROM base, stats
            )
            SELECT * EXCLUDE (mean_rate,mean_rate_1,stddev_rate_1, stddev_rate)
            FROM enhanced 
        """).df()
    
    procc_list.append(procc_file)

dataframe_full = pd.concat(procc_list, ignore_index=True)

## On the column estado in the dataframe_full if there are None values replace them with the string "Otro"
dataframe_full['estado'] = dataframe_full['estado'].fillna('OTRA')
dataframe_full['estado_id'] = dataframe_full['estado'].apply(clean_string)
dataframe_full['school_id'] = dataframe_full['facultad'].apply(clean_string)

dataframe_full['sustentante'] = dataframe_full['sustentante'].fillna(0)
dataframe_full['sustentante'] = dataframe_full['sustentante'].astype(int)
dataframe_full['seleccionado'] = dataframe_full['seleccionado'].fillna(0)
dataframe_full['seleccionado'] = dataframe_full['seleccionado'].astype(int)

# %%
listOfSchools = duckdb.sql("""SELECT 
           school_id, COUNT(*) as apprs 
           FROM dataframe_full 
           GROUP BY school_id 
           HAVING apprs = 1
           ORDER BY school_id DESC""").df()['school_id'].to_list()

# %%
for school_id in listOfSchools:
  
  print(duckdb.sql(f"""
                   WITH base AS (
    SELECT estado,
          facultad,
          school_id,
          year::INTEGER,
          date_id,
          year::INTEGER - LEAD(year::INTEGER) OVER (PARTITION BY school_id ORDER BY year::INTEGER DESC) AS year_gap
      FROM dataframe_full 
      WHERE school_id = '{school_id}'
      ORDER BY year DESC)
      FROM base
      """))
# Out:
# ┌────────────┬─────────────────────────────────────────────┬─────────────────────────────────────────────┬─────────────────────────┬────────────┬──────────┐
# │   estado   │                  facultad                   │                  school_id                  │ CAST("year" AS INTEGER) │  date_id   │ year_gap │
# │  varchar   │                   varchar                   │                   varchar                   │          int32          │  varchar   │  int32   │
# ├────────────┼─────────────────────────────────────────────┼─────────────────────────────────────────────┼─────────────────────────┼────────────┼──────────┤
# │ TAMΔΙ ΊΡΑΣ │ UNIVERSIDAD DEL VALLE DE MEXICO CD VICTORIA │ universidad_del_valle_de_mexico_cd_victoria │                    2014 │ enarm_2014 │     NULL │
# └────────────┴─────────────────────────────────────────────┴─────────────────────────────────────────────┴─────────────────────────┴────────────┴──────────┘
#
# ┌────────────┬────────────────────────────────────────────┬──────────────────────────────────────────┬─────────────────────────┬────────────┬──────────┐
# │   estado   │                  facultad                  │                school_id                 │ CAST("year" AS INTEGER) │  date_id   │ year_gap │
# │  varchar   │                  varchar                   │                 varchar                  │          int32          │  varchar   │  int32   │
# ├────────────┼────────────────────────────────────────────┼──────────────────────────────────────────┼─────────────────────────┼────────────┼──────────┤
# │ NUEVO LEÓN │ UNIV. DEL VALLE DE MÉXICO - CAMPUS CUMBRES │ univ_del_valle_de_mexico__campus_cumbres │                    2024 │ enarm_2024 │     NULL │
# └────────────┴────────────────────────────────────────────┴──────────────────────────────────────────┴─────────────────────────┴────────────┴──────────┘
#
# ┌─────────┬─────────────────────────────────────────┬──────────────────────────────────────┬─────────────────────────┬────────────┬──────────┐
# │ estado  │                facultad                 │              school_id               │ CAST("year" AS INTEGER) │  date_id   │ year_gap │
# │ varchar │                 varchar                 │               varchar                │          int32          │  varchar   │  int32   │
# ├─────────┼─────────────────────────────────────────┼──────────────────────────────────────┼─────────────────────────┼────────────┼──────────┤
# │ DURANGO │ UNIV. AUT. DE DURANGO - CAMPUS SALTILLO │ univ_aut_de_durango__campus_saltillo │                    2024 │ enarm_2024 │     NULL │
# └─────────┴─────────────────────────────────────────┴──────────────────────────────────────┴─────────────────────────┴────────────┴──────────┘
#
# ┌─────────┬───────────────────────────────────────────┬──────────────────────────────────────┬─────────────────────────┬────────────┬──────────┐
# │ estado  │                 facultad                  │              school_id               │ CAST("year" AS INTEGER) │  date_id   │ year_gap │
# │ varchar │                  varchar                  │               varchar                │          int32          │  varchar   │  int32   │
# ├─────────┼───────────────────────────────────────────┼──────────────────────────────────────┼─────────────────────────┼────────────┼──────────┤
# │ NAYARIT │ INST. EST. TEC YSUP. DE MATATIPAC (TEPIq) │ inst_est_tec_ysup_de_matatipac_tepiq │                    2020 │ enarm_2020 │     NULL │
# └─────────┴───────────────────────────────────────────┴──────────────────────────────────────┴─────────────────────────┴────────────┴──────────┘
#
# ┌─────────┬───────────────────────────────────────────────┬─────────────────────────────────────────────┬─────────────────────────┬────────────┬──────────┐
# │ estado  │                   facultad                    │                  school_id                  │ CAST("year" AS INTEGER) │  date_id   │ year_gap │
# │ varchar │                    varchar                    │                   varchar                   │          int32          │  varchar   │  int32   │
# ├─────────┼───────────────────────────────────────────────┼─────────────────────────────────────────────┼─────────────────────────┼────────────┼──────────┤
# │ OAXACA  │ INST. EST. SUPERIORES DE ISTMO DE TEHUANTEPEC │ inst_est_superiores_de_istmo_de_tehuantepec │                    2024 │ enarm_2024 │     NULL │
# └─────────┴───────────────────────────────────────────────┴─────────────────────────────────────────────┴─────────────────────────┴────────────┴──────────┘
#
# ┌─────────┬─────────────────────────────────────────────┬────────────────────────────────────────────┬─────────────────────────┬────────────┬──────────┐
# │ estado  │                  facultad                   │                 school_id                  │ CAST("year" AS INTEGER) │  date_id   │ year_gap │
# │ varchar │                   varchar                   │                  varchar                   │          int32          │  varchar   │  int32   │
# ├─────────┼─────────────────────────────────────────────┼────────────────────────────────────────────┼─────────────────────────┼────────────┼──────────┤
# │ SONORA  │ ESC. IBEROAMERICANA DE CIENCIAS DE LA SALUD │ esc_iberoamericana_de_ciencias_de_la_salud │                    2024 │ enarm_2024 │     NULL │
# └─────────┴─────────────────────────────────────────────┴────────────────────────────────────────────┴─────────────────────────┴────────────┴──────────┘

# %%
duckdb.sql("""
    SELECT 
        *,
        ROUND(
            (acceptance_rate - LAG(acceptance_rate) OVER (PARTITION BY school_id ORDER BY year)) 
            / NULLIF(LAG(acceptance_rate) OVER (PARTITION BY school_id ORDER BY year), 0), 
            2
        ) * 100 AS yoy_growth
    FROM dataframe_full 
    WHERE school_id = 'inst_est_tec_ysup_de_matatipac_tepiq'
    ORDER BY year DESC
    """)
# Out:
# ┌─────────┬───────────────────────────────────────────┬─────────────┬──────────────┬──────────┬─────────────────┬────────────┬─────────┬────────────────────────────┬─────────────────────────────┬─────────┬───────────┬──────────────────────────────────────┬────────────┐
# │ estado  │                 facultad                  │ sustentante │ seleccionado │ promedio │ acceptance_rate │  date_id   │  year   │ acceptance_rate_plus_1_std │ acceptance_rate_minus_1_std │ z_index │ estado_id │              school_id               │ yoy_growth │
# │ varchar │                  varchar                  │    int64    │    int64     │ varchar  │     double      │  varchar   │ varchar │           double           │           double            │ double  │  varchar  │               varchar                │   double   │
# ├─────────┼───────────────────────────────────────────┼─────────────┼──────────────┼──────────┼─────────────────┼────────────┼─────────┼────────────────────────────┼─────────────────────────────┼─────────┼───────────┼──────────────────────────────────────┼────────────┤
# │ NAYARIT │ INST. EST. TEC YSUP. DE MATATIPAC (TEPIq) │           1 │            1 │ 58.22    │           100.0 │ enarm_2020 │ 2020    │                     177.53 │                       22.47 │    0.71 │ nayarit   │ inst_est_tec_ysup_de_matatipac_tepiq │       NULL │
# └─────────┴───────────────────────────────────────────┴─────────────┴──────────────┴──────────┴─────────────────┴────────────┴─────────┴────────────────────────────┴─────────────────────────────┴─────────┴───────────┴──────────────────────────────────────┴────────────┘

# %%
sorted(duckdb.sql(""" SELECT DISTINCT school_id FROM dataframe_full """).df().drop_duplicates()['school_id'].to_list())
# Out:
# ['b_univ_aut_puebla_puebla',
#  'b_univ_aut_puebla_tehuacan',
#  'b_univ_aut_puebla_teziutlan',
#  'centro_est_univ_xochicalco_campus_mexicali',
#  'centro_est_univ_xochicalco_u_ensenada',
#  'centro_est_univ_xochicalco_u_tijuana',
#  'el_campus_universitario_siglo_xxi',
#  'esc_de_medicina_intermedica',
#  'esc_iberoamericana_de_ciencias_de_la_salud',
#  'esc_libre_de_homeopatia_de_mexico',
#  'esc_med_tominaga_nakamoto',
#  'esc_medico__militar_sedena',
#  'esc_medico__naval_semar',
#  'estudios_en_el_extranjero',
#  'inst_de_ciencias_y_estudios_sup_de_tamaulipas',
#  'inst_est_superiores_de_chiapas',
#  'inst_est_superiores_de_chiapas__c_ampus_tapachula',
#  'inst_est_superiores_de_chiapas__campus_tapachula',
#  'inst_est_superiores_de_chiapas__campus_tuxtla_gutierrez',
#  'inst_est_superiores_de_chiapas_campus_tuxtla_gutierrez',
#  'inst_est_superiores_de_chiapascampus_tuxtla_gutierrez',
#  'inst_est_superiores_de_istmo_de_tehuantepec',
#  'inst_est_superiores_tepeaca',
#  'inst_est_tec_y_sup_de_matatipac_tepic',
#  'inst_est_tec_ysup_de_matatipac_tepiq',
#  'inst_tecnologico_est_sup_monterrey',
#  'inst_tecnologico_est_sup_mty',
#  'inst_tecnologico_est_sup_mty__campus_cdmx',
#  'inst_tecnologico_est_sup_mty__campus_jalisco',
#  'inst_tecnologico_est_sup_mty__campus_mty',
#  'inst_univ_de_ciencias_medicas_y_humanisticas_de_nayarit',
#  'inst_univ_de_la_salud_del_estado_de_mexico',
#  'ipn_centro_interdisciplinario_de_c',
#  'ipn_centro_interdisciplinario_de_c_salud',
#  'ipn_esc_nal_med_y_homeopatia',
#  'ipn_esc_sup_medicina',
#  'ipn_escsup_medicina',
#  'medicos_extranjeros',
#  'otra',
#  'saint_lukes_school_of_medicine',
#  'unam_campus_veracruz',
#  'unam_fes_iztacala',
#  'unam_fes_zaragoza',
#  'unam_fm_cu',
#  'univ_anahuac',
#  'univ_anahuac__campus_xalapa',
#  'univ_anahuac__cancun',
#  'univ_anahuac__inst_est_sup_de_tamaulipas',
#  'univ_anahuac_inst_est_sup_de_tamaulipas',
#  'univ_anahuac_oaxaca',
#  'univ_anahuac_puebla',
#  'univ_anahuac_queretaro',
#  'univ_aut_benito_juarez_de_oaxaca',
#  'univ_aut_de_aguascalientes',
#  'univ_aut_de_bc__campus_valle_de_las_palmas',
#  'univ_aut_de_bc_u_ensenada',
#  'univ_aut_de_bc_u_mexicali',
#  'univ_aut_de_bc_u_tijuana',
#  'univ_aut_de_campeche',
#  'univ_aut_de_cd_juarez',
#  'univ_aut_de_chiapas',
#  'univ_aut_de_chihuahua',
#  'univ_aut_de_chihuahua__campus_hidalgo_del_parral',
#  'univ_aut_de_coahuila_u_saltillo',
#  'univ_aut_de_coahuila_u_torreon',
#  'univ_aut_de_durango__campus_culiacan',
#  'univ_aut_de_durango__campus_durango',
#  'univ_aut_de_durango__campus_gomez_palacios',
#  'univ_aut_de_durango__campus_los_mochis',
#  'univ_aut_de_durango__campus_mazatlan',
#  'univ_aut_de_durango__campus_saltillo',
#  'univ_aut_de_durango__campus_torreon',
#  'univ_aut_de_durango__campus_zacatecas',
#  'univ_aut_de_durango_campus_durango',
#  'univ_aut_de_durango_campus_gomez_palacios',
#  'univ_aut_de_durango_campus_los_mochis',
#  'univ_aut_de_durango_campus_mazatlan',
#  'univ_aut_de_durango_campus_zacatecas',
#  'univ_aut_de_guadalajara',
#  'univ_aut_de_guadalajara_campus_tabasco',
#  'univ_aut_de_guerrero',
#  'univ_aut_de_hidalgo',
#  'univ_aut_de_morelos',
#  'univ_aut_de_nayarit',
#  'univ_aut_de_nuevo_leon',
#  'univ_aut_de_queretaro',
#  'univ_aut_de_san_luis_potosi',
#  'univ_aut_de_sinaloa',
#  'univ_aut_de_tamps_u_matamoros',
#  'univ_aut_de_tamps_u_tampico',
#  'univ_aut_de_tlaxcala',
#  'univ_aut_de_veracruz_villa_rica',
#  'univ_aut_de_yucatan',
#  'univ_aut_de_zacatecas',
#  'univ_aut_del_carmen_campeche',
#  'univ_aut_del_edo_de_mexico',
#  'univ_aut_deledo_de_mexico',
#  'univ_aut_espana_de_durango',
#  'univ_aut_metropolitana_u_xochimilco',
#  'univ_cristobal_colon__veracruz',
#  'univ_cuahutemoc',
#  'univ_cuauhtemoc__campus_aguascalientes',
#  'univ_cuauhtemoc__plantel_aguascalientes',
#  'univ_cuauhtemoc__plantel_guadalajara',
#  'univ_cuauhtemoc__plantel_san_luis_potosi',
#  'univ_cuauhtemoc_campus_aguascalientes',
#  'univ_cuauhtemoc_plantel_guadalajara',
#  'univ_cuauhtemoc_plantel_san_luis_potosi',
#  'univ_de_celaya',
#  'univ_de_colima',
#  'univ_de_durango__campus_cd_juarez',
#  'univ_de_durango_campus_cd_juarez',
#  'univ_de_guadalajara',
#  'univ_de_guadalajara_centro_universitario_de_la_costa',
#  'univ_de_guadalajara_centro_universitario_de_tonala',
#  'univ_de_guadalajara_centro_universitario_del_sur',
#  'univ_de_guadalajara_u_cd_guzman',
#  'univ_de_guadalajara_u_los_altos',
#  'univ_de_guanajuato',
#  'univ_de_monterrey',
#  'univ_de_quintana_roo',
#  'univ_de_sonora',
#  'univ_del_mayab',
#  'univ_del_noreste',
#  'univ_del_soconusco__sede_tapachula',
#  'univ_del_sur_chiapas',
#  'univ_del_sureste_chiapas',
#  'univ_del_valle_de_atemajac',
#  'univ_del_valle_de_mexico__campus_cd_reynosa',
#  'univ_del_valle_de_mexico__campus_cd_victoria',
#  'univ_del_valle_de_mexico__campus_cumbres',
#  'univ_del_valle_de_mexico__campus_hermosillo',
#  'univ_del_valle_de_mexico__campus_jalisco',
#  'univ_del_valle_de_mexico__campus_od_reynosa',
#  'univ_del_valle_de_mexico__campus_od_victoria',
#  'univ_del_valle_de_mexico__campus_saltillo',
#  'univ_del_valle_de_mexico__campus_san_luis_potosi',
#  'univ_del_valle_de_mexico__campus_sur_coyoacan',
#  'univ_del_valle_de_mexico__campus_veracruz',
#  'univ_del_valle_de_mexico__campus_villahermosa',
#  'univ_del_valle_de_mexico__campus_zapopan',
#  'univ_del_valle_de_mexico_campus_qro',
#  'univ_delsoconusco__sede_tapachula',
#  'univ_durango__campus_chihuahua',
#  'univ_durango_campus_chihuahua',
#  'univ_durango_santander',
#  'univ_guadalajara_lamar',
#  'univ_guadalajara_lamar__campus_inglaterra',
#  'univ_guadalajara_lamar__campus_vallarta',
#  'univ_hipocrates',
#  'univ_jose_marti',
#  'univ_juarez_aut_de_tabasco',
#  'univ_juarez_aut_de_tabasco__campus_comalcalco',
#  'univ_juarez_aut_de_tabasco_division_academica',
#  'univ_juarez_del_edo_durango_u_durango',
#  'univ_juarez_del_edo_durango_u_gomez_palacio',
#  'univ_juarez_del_edo_durango_u_gomezpalacio',
#  'univ_juarezaut_de_tabasco',
#  'univ_juarezaut_de_tabasco_campus_comalcalco',
#  'univ_juarezaut_de_tabasco_division_academica',
#  'univ_justo_sierra',
#  'univ_la_salle',
#  'univ_la_salle__campus_cd_victoria',
#  'univ_la_salle__campus_od_victoria',
#  'univ_las_americas_puebla',
#  'univ_latina_de_mexico',
#  'univ_latinoamericana',
#  'univ_marista_de_merida',
#  'univ_mexicoamericana_del_norte',
#  'univ_mich_de_san_nicolas_de_hidalgo_morelia',
#  'univ_mich_de_san_nicolas_de_hidalgo_zamora',
#  'univ_mich_desan_nicolas_de_hidalgo_zamora',
#  'univ_montemorelos',
#  'univ_olmeca',
#  'univ_pablo_guardado_chavez',
#  'univ_panamericana',
#  'univ_politecnica_de_pachuca',
#  'univ_popular_aut_del_edo_puebla',
#  'univ_popularaut_deledq_puebla',
#  'univ_quetzalcoatl',
#  'univ_quetzalcoatl_de_irapuato',
#  'univ_regional_del_sureste',
#  'univ_valle_del_bravo_u_cd_victoria',
#  'univ_valle_del_bravo_u_u_reynosa',
#  'univ_vasco_de_quiroga__campus_santa_maria',
#  'univ_veracruzana_u_cd_mendoza',
#  'univ_veracruzana_u_cd_minatitlan',
#  'univ_veracruzana_u_jalapa',
#  'univ_veracruzana_u_od_minatitlan',
#  'univ_veracruzana_u_poza_rica',
#  'univ_veracruzana_u_veracruz',
#  'univ_veracruzana_u_xalapa',
#  'univ_west_hill_institute_sc',
#  'universidad_de_guadalajara_centro_universitario_de_la_costa',
#  'universidad_de_ixtlahuaca_cui',
#  'universidad_del_valle_de_atemajac_univa',
#  'universidad_del_valle_de_cuernavaca',
#  'universidad_del_valle_de_mexico_cd_victoria',
#  'universidad_del_valle_de_mexico_hermosillo_sonora',
#  'universidad_del_valle_de_mexico_villa_hermosa_tabasco',
#  'universidad_guadalajara_lamar',
#  'universidad_indesag',
#  'universidad_intercultural_de_chiapas',
#  'universidad_latina_de_mexico_celaya_guanajuato',
#  'universidades_para_el_bienestar_benito_juarez_garcia']
